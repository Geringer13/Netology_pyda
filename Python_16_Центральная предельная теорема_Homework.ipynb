# %% [markdown]
# <a href="https://colab.research.google.com/github/yustinaivanova/netology_statistics/blob/master/dz_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Виды распределений

# %% [markdown]
# Загрузить таблицу и построить график распределений. Найти нормальное распределение.

# %%
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import io
import requests
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# Таблица цен на дома в Бостоне

# %%
# Основные значения:

# * CRIM: This is the per capita crime rate by town
# * ZN: This is the proportion of residential land zoned for lots larger than 25,000 sq.ft.
# * INDUS: This is the proportion of non-retail business acres per town.
# * CHAS: This is the Charles River dummy variable (this is equal to 1 if tract bounds river; 0 otherwise)
# * NOX: This is the nitric oxides concentration (parts per 10 million)
# * RM: This is the average number of rooms per dwelling
# * AGE: This is the proportion of owner-occupied units built prior to 1940
# * DIS: This is the weighted distances to five Boston employment centers
# * RAD: This is the index of accessibility to radial highways
# * TAX: This is the full-value property-tax rate per 10,000 dollars
# * PTRATIO: This is the pupil-teacher ratio by town
# * B: This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town
# * LSTAT: This is the percentage lower status of the population
# * MEDV: This is the median value of owner-occupied homes in 1000 dollars

# %%
url='http://yustiks.ru/housing.csv'
s=requests.get(url).content
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data=pd.read_csv(io.StringIO(s.decode('utf-8')),  delim_whitespace=True, names=names)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# Нарисовать частотные графики для всех значений. Можете ли вы найти следующие распределения в данных графиках?
#
#
# 1.   Нормальное
# 2.   Равномерное
# 3.   Биноминальное
# 4.   Бернулли
# 5.   Геометрическое
# 6.   Логнормальное

# %%
# Exponenteial
plt.hist(data['CRIM'], 15)
plt.show()

# %%
# almost Exponenteial
plt.hist(data['ZN'], 10)
plt.show()

# %%
# incomprehensible
plt.hist(data['INDUS'], 50)
plt.show()

# %%
# Bernoulli
plt.hist(data['CHAS'], 15)
plt.show()

# %%
# incomprehensible
plt.hist(data['NOX'], 35)
plt.show()

# %%
# Normal
plt.hist(data['RM'], 15)
plt.show()

# %%
# Exponenteial
plt.hist(data['AGE'], 35)
plt.show()

# %%
# Log normal or Poisson
plt.hist(data['DIS'], 105)
plt.show()

# %%
# incomprehensible
plt.hist(data['RAD'], 15)
plt.show()

# %%
# incomprehensible
plt.hist(data['TAX'], 15)
plt.show()

# %%
# incomprehensible
plt.hist(data['PTRATIO'], 15)
plt.show()

# %%
# Exponenteial
plt.hist(data['B'], 15)
plt.show()

# %%
# Poison
plt.hist(data['LSTAT'], 40)
plt.show()

# %%
# Binomial
plt.hist(data['MEDV'], 50)
plt.show()

# %% [markdown]
# Написать **линейную регрессию** на два атрибута. Допустим, мы хотим предсказать цену дома (MEDV) в Бостоне, зная что цена на дом имеет линейную зависимость с атрибутом LSTAT.

# %% [markdown]
# 1.   Разделить данные на 80% тренировочных, 20% тестовых
# 2.   Составить модель линейной регрессии
# 3.   Посчитать ошибку модели на тестовых данных
# 4.   Сделать точечный график данных и полученной прямой линейной регрессии

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
# Corellation figure medium_value vs low_population
low_population = data['LSTAT']
medium_value = data['MEDV']
plt.scatter(x = medium_value, y = low_population)
plt.xlabel('medium_value')
plt.ylabel('low_population')
plt.title('Corr medium_value vs low_population')
# Out:
# Text(0.5, 1.0, 'Corr medium_value vs low_population')

# %%
low_population_1 = low_population - low_population.mean()

# %%
medium_value_1 = medium_value - medium_value.mean()

# %%
# Поэксперементировал с нормализацией и масштабированием, разницы никакой нет, что до, что после. Так же посчитал коэффициент
# Пирсона, он равен -0.73, что говорит об обратной корелляции.
from scipy.stats import pearsonr
corr, p_value = pearsonr(medium_value, low_population)
print(corr, p_value)

from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(-1,1))

low_population_2 = min_max_scaler.fit_transform(np.array(low_population_1).reshape(-1, 1))
print(min(low_population_2))
print(max(low_population_2))

medium_value_2 = min_max_scaler.fit_transform(np.array(medium_value_1).reshape(-1, 1))
print(min(medium_value_2))
print(max(medium_value_2))
# Out:
# -0.7376627261740147 5.081103394389002e-88
# [-1.]
# [1.]
# [-1.]
# [1.]

# %%
plt.scatter(x = medium_value_2, y = low_population_2)
plt.xlabel('medium_value')
plt.ylabel('low_population')
plt.title('Corr medium_value vs low_population')
# Out:
# Text(0.5, 1.0, 'Corr medium_value vs low_population')

# %%
low_population_1 = np.array(low_population).reshape(-1,1)
medium_value_1 = np.array(medium_value).reshape(-1,1)

# %%
# Разделим выборку 80% тренировочных и 20% тестовых
from sklearn.linear_model import LinearRegression
model = LinearRegression()

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    medium_value_1,
    low_population_1,
    test_size = 0.2,
    random_state = 3
)

# %%
# Обучим модель
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Точность данных 56%, соответственно ошибка 44%, что является много
predicted_y = model.predict(X_test)
model.score(X_test, y_test)
# Out:
# 0.5663680841829948

# %%
# Интересное наблюдение, чем меньше значение test_size = 0.1 или test_size = 0.05, тем вы процент 
# точности model.score(X_test, y_test, но не существенно, процентов на 5 :)

# %%
# Обратная корелляция, чем ниже популяция тем выше цена на недвижимость, что и логично, меньше народу большу кислорода. :)
sns.regplot(x = medium_value, y = low_population, data = data, fit_reg = True)
plt.xlabel('medium_value')
plt.ylabel('low_population')
plt.title('linear cor regression medium_value vs low_population')
# Out:
# Text(0.5, 1.0, 'linear cor regression medium_value vs low_population')

# %% [markdown]
# Загрузить таблицу Happiness report. Посчитать матрицу ковариаций попарно.

# %%
dataframe=pd.read_csv('world-happiness-report-2019.csv')
dataframe.columns=['country', 'ladder', 'sd_of_ladder', 'positive_affect', 'negative_affect', 'social_support', 
            'freedom', 'corruption', 'generosity', 'log_of_gdp_per_capita', 'healthy_life_expectancy']
dataframe.head()
# Out:
#        country  ladder  sd_of_ladder  positive_affect  negative_affect  \
# 0      Finland       1             4             41.0             10.0
# 1      Denmark       2            13             24.0             26.0
# 2       Norway       3             8             16.0             29.0
# 3      Iceland       4             9              3.0              3.0
# 4  Netherlands       5             1             12.0             25.0
#
#    social_support  freedom  corruption  generosity  log_of_gdp_per_capita  \
# 0             2.0      5.0         4.0        47.0                   22.0
# 1             4.0      6.0         3.0        22.0                   14.0
# 2             3.0      3.0         8.0        11.0                    7.0
# 3             1.0      7.0        45.0         3.0                   15.0
# 4            15.0     19.0        12.0         7.0                   12.0
#
#    healthy_life_expectancy
# 0                     27.0
# 1                     23.0
# ...

# %%
# Считаем матрицу ковариации, без первых 3-х столбцов.
df_cov = dataframe.iloc[:,3:]
df_cov = df_cov.dropna()
normalize = (df_cov - df_cov.mean()) / df_cov.std()
df_cov.head()
# Out:
#    positive_affect  negative_affect  social_support  freedom  corruption  \
# 0             41.0             10.0             2.0      5.0         4.0
# 1             24.0             26.0             4.0      6.0         3.0
# 2             16.0             29.0             3.0      3.0         8.0
# 3              3.0              3.0             1.0      7.0        45.0
# 4             12.0             25.0            15.0     19.0        12.0
#
#    generosity  log_of_gdp_per_capita  healthy_life_expectancy
# 0        47.0                   22.0                     27.0
# 1        22.0                   14.0                     23.0
# 2        11.0                    7.0                     12.0
# 3         3.0                   15.0                     13.0
# 4         7.0                   12.0                     18.0

# %%
np.cov(df_cov)
np.round_(np.cov(normalize.T), decimals=2)
# Out:
# array([[1.  , 0.35, 0.43, 0.7 , 0.23, 0.42, 0.31, 0.34],
#        [0.35, 1.  , 0.67, 0.42, 0.17, 0.35, 0.57, 0.51],
#        [0.43, 0.67, 1.  , 0.48, 0.15, 0.45, 0.8 , 0.76],
#        [0.7 , 0.42, 0.48, 1.  , 0.41, 0.5 , 0.39, 0.42],
#        [0.23, 0.17, 0.15, 0.41, 1.  , 0.28, 0.19, 0.15],
#        [0.42, 0.35, 0.45, 0.5 , 0.28, 1.  , 0.46, 0.45],
#        [0.31, 0.57, 0.8 , 0.39, 0.19, 0.46, 1.  , 0.87],
#        [0.34, 0.51, 0.76, 0.42, 0.15, 0.45, 0.87, 1.  ]])

# %%
np.round(df_cov.corr(), decimals=2)
# Out:
#                          positive_affect  negative_affect  social_support  \
# positive_affect                     1.00             0.35            0.43
# negative_affect                     0.35             1.00            0.67
# social_support                      0.43             0.67            1.00
# freedom                             0.70             0.42            0.48
# corruption                          0.23             0.17            0.15
# generosity                          0.42             0.35            0.45
# log_of_gdp_per_capita               0.31             0.57            0.80
# healthy_life_expectancy             0.34             0.51            0.76
#
#                          freedom  corruption  generosity  \
# positive_affect             0.70        0.23        0.42
# negative_affect             0.42        0.17        0.35
# social_support              0.48        0.15        0.45
# freedom                     1.00        0.41        0.50
# ...

# %% [markdown]
# Сколько в данной таблице отсутствующих значений? Написать ответ. Если есть отсутствующие значения в выборке country, убрать (drop). Написать код.

# %%
# В столбце country нет отсутсвующих значений, но они естть в других столбцах. Из метода shape видно, что в 16 строках есть
# отсутствующие значения, для их удаления используется метод dropna
dataframe.info()
dataframe.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
# country                    156 non-null object
# ladder                     156 non-null int64
# sd_of_ladder               156 non-null int64
# positive_affect            155 non-null float64
# negative_affect            155 non-null float64
# social_support             155 non-null float64
# freedom                    155 non-null float64
# corruption                 148 non-null float64
# generosity                 155 non-null float64
# log_of_gdp_per_capita      152 non-null float64
# healthy_life_expectancy    150 non-null float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 13.5+ KB
# (156, 11)

# %%
dataframe_1 = dataframe.dropna()
dataframe_1.info()
dataframe_1.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140 entries, 0 to 155
# Data columns (total 11 columns):
# country                    140 non-null object
# ladder                     140 non-null int64
# sd_of_ladder               140 non-null int64
# positive_affect            140 non-null float64
# negative_affect            140 non-null float64
# social_support             140 non-null float64
# freedom                    140 non-null float64
# corruption                 140 non-null float64
# generosity                 140 non-null float64
# log_of_gdp_per_capita      140 non-null float64
# healthy_life_expectancy    140 non-null float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 13.1+ KB
# (140, 11)

# %% [markdown]
# Сколько стран в выборке? Написать ответ.

# %%
len(dataframe['country'])
# Out:
# 156

# %%
dataframe['country'].head()
# Out:
# 0        Finland
# 1        Denmark
# 2         Norway
# 3        Iceland
# 4    Netherlands
# Name: country, dtype: object

# %%
dataframe['country'].tail()
# Out:
# 151                      Rwanda
# 152                    Tanzania
# 153                 Afghanistan
# 154    Central African Republic
# 155                 South Sudan
# Name: country, dtype: object

# %% [markdown]
# Добавить новую колонку в таблицу - 'continent'. Каждая страна относится к определенному материку. Всего материко 6:
# *   Евразия,
# *   Африка,
# *   Северная Америка,
# *   Южная Америка,
# *   Австралия,
# *   Антарктида.
#
# Таким образом, мы можем классифицировать каждый элемент как член определенного класса - континента.

# %%
continents = pd.read_csv('continents.csv', sep = ';')
continents.columns=['country', 'continent']
continents.head()
# Out:
#      country continent
# 0  Mauritius    Africa
# 1      Libya    Africa
# 2    Nigeria    Africa
# 3    Algeria    Africa
# 4    Morocco    Africa

# %%
dataframe = dataframe.merge(continents, on='country', how='left')

# %%
dataframe_1 = dataframe.iloc[:,3:]
dataframe_1 = dataframe_1.dropna()
dataframe_1.head()
# Out:
#    positive_affect  negative_affect  social_support  freedom  corruption  \
# 0             41.0             10.0             2.0      5.0         4.0
# 1             24.0             26.0             4.0      6.0         3.0
# 2             16.0             29.0             3.0      3.0         8.0
# 3              3.0              3.0             1.0      7.0        45.0
# 4             12.0             25.0            15.0     19.0        12.0
#
#    generosity  log_of_gdp_per_capita  healthy_life_expectancy continent
# 0        47.0                   22.0                     27.0  Euroasia
# 1        22.0                   14.0                     23.0  Euroasia
# 2        11.0                    7.0                     12.0  Euroasia
# 3         3.0                   15.0                     13.0  Euroasia
# 4         7.0                   12.0                     18.0  Euroasia

# %%
compare_1 = dataframe_1.filter(items=['positive_affect', 'negative_affect', 'social_support', 'freedom', 'continent'])
sns.set(style="ticks", color_codes=True)
g = sns.pairplot(data = compare_1, hue='continent')
plt.show()

# %%
compare_2 = dataframe_1.filter(items=['corruption', 'generosity', 'log_of_gdp_per_capita', 'healthy_life_expectancy', 'continent'])
sns.set(style="ticks", color_codes=True)
g = sns.pairplot(data = compare_2, hue='continent')
plt.show()

# %%
compare_3 = dataframe_1.filter(items=['positive_affect', 'negative_affect', 'log_of_gdp_per_capita', 'healthy_life_expectancy', 'continent'])
sns.set(style="ticks", color_codes=True)
g = sns.pairplot(data = compare_3, hue='continent')
plt.show()

# %%
compare_4 = dataframe_1.filter(items=['social_support', 'freedom', 'continent', 'corruption', 'generosity'])
sns.set(style="ticks", color_codes=True)
g = sns.pairplot(data = compare_4, hue='continent')
plt.show()

# %%
compare_5 = dataframe_1.filter(items=['social_support', 'freedom', 'continent', 'log_of_gdp_per_capita', 'healthy_life_expectancy', ])
sns.set(style="ticks", color_codes=True)
g = sns.pairplot(data = compare_5, hue='continent')
plt.show()

# %%
compare_1 = dataframe_1.filter(items=['positive_affect', 'negative_affect', 'social_support', 'corruption', 'generosity', 'continent'])
sns.set(style="ticks", color_codes=True)
g = sns.pairplot(data = compare_1, hue='continent')
plt.show()

# %% [markdown]
# Нарисовать sns.pairplot для класса - континет. Из графика сделать вывод о том, какие континеты похожи.

# %% [markdown]
# Построить матрицу корреляций для таблицы. Какие можно сделать выводы?

# %% [markdown]
# **Регрессионный анализ** - можно ли провести линейную зависимость между двумя выборками. Возьмем Ladder - удовлетворение жизнью, и generosity - доброта. Мы хотим найти прямую, которая разделит точки в пространстве наполовину. Это можно сделать графически. Нарисовать график. Можно ли сказать, что данная прямая является собственным вектором? Сделать график регрессионной прямой на данных и собственных векторов.

# %%
dataframe = dataframe.dropna()
ladder = dataframe['ladder']
generosity = dataframe['generosity']
corr_1, p_value_1 = pearsonr(ladder, generosity)
print(corr_1, p_value_1)
sns.regplot(x=generosity , y=ladder,data=dataframe, fit_reg=True)
# Out:
# 0.4857039734511727 1.1812651225114376e-09

# %%
# Нельзя сказать, что прямая явлется собственным вектором
import numpy.linalg as la
import math
from sklearn.preprocessing import StandardScaler

Y = np.vstack((generosity, ladder)).T
w,v = la.eig(np.cov(Y.T))
print(np.cov(Y.T))

for i in range(len(w)):
    fig = plt.gcf()
    fig.set_size_inches(6,6)
    plt.suptitle('Собственный вектор № '+ str(i+1), fontsize=16)    
    plt.plot(generosity, ladder, 'g.', zorder=1)
    print('Собственное значение: ', round(w[i],2), 'Собственный вектор: ', v[:,i])
    plt.xlabel('generosity')
    plt.xlim(-10,175)
    plt.ylabel('ladder')
    plt.ylim(-10,175)
    plt.plot([generosity.mean(), generosity.mean() + (w[i]) * v[:,i][0]], 
             [ladder.mean(), ladder.mean() + (w[i]) * v[:,i][1]],color='red', linewidth=3)
    plt.show()
# Out:
# [[2000.57446043  992.82230216]
#  [ 992.82230216 2088.55066804]]
# Собственное значение:  1050.77 Собственный вектор:  [-0.72258657  0.69128044]
# Собственное значение:  3038.36 Собственный вектор:  [-0.69128044 -0.72258657]

# %% [markdown]
# # Дискретное распределение случайной величины

# %% [markdown]
# Напишите код для моделирования 10 подбрасываний игрального кубика. Начертите диаграму histogram. Какое это распределение?

# %%
trials = 10
values = np.random.randint(1, 7, size=trials)
sns.distplot(values10)

# %%
# моделируйте 1000 раз сумму по 100 подбрасываний. Начертите диаграму histogram. 
# Почему график изменился? Почему можно применить центральную предельную теорему?

# %%
# Любое распределение стремиться к нормальному (Гаусса). Чем больше экспериментов тем сильнее любое распределение стремится
# к нормальному.
experiments = 1000
trials_100 = 100
outcomes = np.empty(experiments, dtype=np.float)

for i in range(experiments):
    values_100 = np.random.randint(1, 7, size=trials_100)
    head_counts = np.sum(values_100)
    outcomes[i] = head_counts
    
sns.distplot(values_100)
